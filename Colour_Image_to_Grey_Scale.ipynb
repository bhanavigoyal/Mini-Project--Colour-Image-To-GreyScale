# %% [markdown]
# <a href="https://colab.research.google.com/github/bhanavigoyal/Mini-Project--Colour-Image-To-GreyScale/blob/main/Colour_Image_to_Grey_Scale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('/content/Colour Images/687px-Mona_Lisa,_by_Leonardo_da_Vinci,_from_C2RMF_retouched.jpg')
cv2_imshow(image)
grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(grayscale)
# Out:
# <PIL.Image.Image image mode=RGB size=687x1024 at 0x7F46D4887EB0>
# <PIL.Image.Image image mode=L size=687x1024 at 0x7F46D4887EB0>
